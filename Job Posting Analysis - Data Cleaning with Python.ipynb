# %% [markdown]
# ## Title: Job Posting analysis and Data Cleaning using Python
#
# ### Introduction:
#
# In today's job market, data plays a crucial role in making informed decisions for both job seekers and employers. In this project, we used Python to analyze job postings with the goal of finding meaningful information that will be useful to recruiters, employers, and job seekers alike.
#
# ### Project Objectives:
#
# Our goal is to extract valuable information that can help stakeholders with hiring procedures, workforce planning, and job searches.

# %%
### import necessary libraries

# For data analysis
import pandas as pd
import numpy as np

# %%
# For data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# Load the dataset
df = pd.read_csv(r"C:\Users\ADMIN\Desktop\Project 3\transformed_jobs_data.csv")

# %%
df.head()
# Out:
#                      job_id job_employment_type  \
# 0  XX6946dvNO3187IkAAAAAA==            FULLTIME
# 1  6Wu7QcWfrhOR-THoAAAAAA==            FULLTIME
# 2  Oiu186OT5E6bkZReAAAAAA==            FULLTIME
# 3  5y7azm6gLeu1ab_9AAAAAA==            FULLTIME
# 4  CJUJsgmqVdDmJmHgAAAAAA==            FULLTIME
#
#                                            job_title  \
# 0                                      Data Engineer
# 1                                      Data Engineer
# 2  2024 RBCIS, Summer Co-op Data Engineer / Full ...
# 3                                 Lead Data Engineer
# 4  2024 Investor Services - Business Data Analyst...
#
#                                       job_apply_link  \
# 0  https://ca.linkedin.com/jobs/view/data-enginee...
# 1  https://ca.linkedin.com/jobs/view/data-enginee...
# 2  https://ca.linkedin.com/jobs/view/2024-rbcis-s...
# 3  https://ca.linkedin.com/jobs/view/lead-data-en...
# 4  https://jobs.rbc.com/ca/en/job/R-0000074144/20...
#
#                                      job_description  job_city job_country  \
# 0  • *Please note that our offices will be closed...  Montréal          CA
# 1  We are seeking an experienced and passionate D...       NaN          CA
# 2  Job Summary\n\nJob Description\n\nWhat is the ...   Toronto          CA
# 3  Overview\n\nAt Nortal, we are driven by a gran...       NaN          CA
# 4  Job Summary\n\nWhat is the opportunity?\n\nAs ...   Toronto          CA
#
#   job_posted_at_timestamp       employer_website employer_company_type
# 0        12/19/2023 20:22                    NaN                   NaN
# 1        12/19/2023 15:55                    NaN                   NaN
# 2        12/19/2023 22:30     http://www.rbc.com               Finance
# 3        12/19/2023 17:06  http://www.nortal.com     Computer Services
# 4         12/20/2023 0:00     http://www.rbc.com               Finance

# %%
df.tail()
# Out:
#                        job_id job_employment_type                   job_title  \
# 161  0JxLam0cJtXsmjQZAAAAAA==            FULLTIME  Senior Cloud Data Engineer
# 162  EGvoxwF7K6W0LOMtAAAAAA==            FULLTIME  Senior Cloud Data Engineer
# 163  TvhAbNPDfD24fyHVAAAAAA==            FULLTIME  Senior Cloud Data Engineer
# 164  6N_3eAHv_8HXYM0cAAAAAA==            FULLTIME  Senior Cloud Data Engineer
# 165  iQu2KNPFHbJstSZuAAAAAA==            FULLTIME  Senior Cloud Data Engineer
#
#                                         job_apply_link  \
# 161  https://www.linkedin.com/jobs/view/senior-clou...
# 162  https://www.linkedin.com/jobs/view/senior-clou...
# 163  https://www.linkedin.com/jobs/view/senior-clou...
# 164  https://www.linkedin.com/jobs/view/senior-clou...
# 165  https://www.linkedin.com/jobs/view/senior-clou...
#
#                                        job_description         job_city  \
# 161  Job Description\n\nJob Summary:\n\nThis positi...        Las Vegas
# 162  Job Description\n\nJob Summary:\n\nThis positi...         Richmond
# 163  Job Description\n\nJob Summary:\n\nThis positi...       Fort Worth
# 164  Job Description\n\nJob Summary:\n\nThis positi...         Columbus
# 165  Job Description\n\nJob Summary:\n\nThis positi...  Fort Lauderdale
#
#     job_country job_posted_at_timestamp    employer_website  \
# 161          US        12/19/2023 12:11  http://www.bdo.com
# 162          US        12/19/2023 10:42  http://www.bdo.com
# 163          US        12/19/2023 11:52  http://www.bdo.com
# 164          US        12/19/2023 12:15  http://www.bdo.com
# 165          US        12/19/2023 12:11  http://www.bdo.com
#
#     employer_company_type
# 161            Consulting
# 162            Consulting
# 163            Consulting
# 164            Consulting
# 165            Consulting

# %%
df.shape
# Out:
# (166, 10)

# %%
 df.columns
# Out:
# Index(['job_id', 'job_employment_type', 'job_title', 'job_apply_link',
#        'job_description', 'job_city', 'job_country', 'job_posted_at_timestamp',
#        'employer_website', 'employer_company_type'],
#       dtype='object')

# %%
# Data verification - Data type, number of features and rows, missing data, e.t.c
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 166 entries, 0 to 165
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   job_id                   166 non-null    object
#  1   job_employment_type      166 non-null    object
#  2   job_title                166 non-null    object
#  3   job_apply_link           166 non-null    object
#  4   job_description          166 non-null    object
#  5   job_city                 128 non-null    object
#  6   job_country              166 non-null    object
#  7   job_posted_at_timestamp  166 non-null    object
#  8   employer_website         113 non-null    object
#  9   employer_company_type    76 non-null     object
# dtypes: object(10)
# memory usage: 13.1+ KB

# %%
{x: len(df[x].unique())for x in df.columns}
# Out:
# {'job_id': 166,
#  'job_employment_type': 4,
#  'job_title': 99,
#  'job_apply_link': 166,
#  'job_description': 153,
#  'job_city': 71,
#  'job_country': 3,
#  'job_posted_at_timestamp': 139,
#  'employer_website': 89,
#  'employer_company_type': 14}

# %%
df.describe()
# Out:
#                           job_id job_employment_type      job_title  \
# count                        166                 166            166
# unique                       166                   4             99
# top     XX6946dvNO3187IkAAAAAA==            FULLTIME  Data Engineer
# freq                           1                 153             31
#
#                                            job_apply_link  \
# count                                                 166
# unique                                                166
# top     https://ca.linkedin.com/jobs/view/data-enginee...
# freq                                                    1
#
#                                           job_description job_city  \
# count                                                 166      128
# unique                                                153       70
# top     Job Description\n\nJob Summary:\n\nThis positi...   London
# freq                                                   14       29
#
#        job_country job_posted_at_timestamp    employer_website  \
# count          166                     166                 113
# unique           3                     139                  88
# top             US         12/20/2023 0:00  http://www.bdo.com
# freq            73                       7                  14
#
#        employer_company_type
# count                     76
# unique                    13
# top                  Finance
# freq                      18

# %%
# Convert 'job_posted_at_timestamp' to datetime
df['job_posted_at_timestamp'] = pd.to_datetime(df['job_posted_at_timestamp'])

# %%
# Analyze the distribution of job postings over time
job_postings_over_time = df['job_posted_at_timestamp'].dt.date.value_counts().sort_index()
print("\nJob Postings Over Time:")
print(job_postings_over_time)
# Out:
# Job Postings Over Time:
# 2023-12-19    144
# 2023-12-20     22
# Name: job_posted_at_timestamp, dtype: int64

# %%
# Check for duplicates
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Data Cleaning

# %%
# Check for missing values
print(df.isnull().sum())

# Visualization the missing data
plt.figure(figsize = (10,3))
sns.heatmap(df.isnull(), cbar=True, cmap="Blues_r")
# Out:
# job_id                      0
# job_employment_type         0
# job_title                   0
# job_apply_link              0
# job_description             0
# job_city                   38
# job_country                 0
# job_posted_at_timestamp     0
# employer_website           53
# employer_company_type      90
# dtype: int64
# <Axes: >

# %%
# job_city is a categorical data
df['job_city'].mode()[0]
# Out:
# 'London'

# %%
# Replace the missing values with mode
df['job_city']=df['job_city'].fillna(df['job_city'].mode()[0])

# %%
df['job_city'].isnull().sum()
# Out:
# 0

# %%
# employer_company_type is a categorical data
df['employer_company_type'].mode()[0]
# Out:
# 'Consulting'

# %%
# Replace the missing values with mode
df['employer_company_type']=df['employer_company_type'].fillna(df['employer_company_type'].mode()[0])

# %%
df['employer_company_type'].isnull().sum()
# Out:
# 0

# %%
# employer_website is a categorical data
df['employer_website'].mode()[0]
# Out:
# 'http://www.bdo.com'

# %%
# Replace the missing values with mode
df['employer_website']=df['employer_website'].fillna(df['employer_website'].mode()[0])

# %%
df['employer_website'].isnull().sum()
# Out:
# 0

# %%
# Cleaning job_posted_at_timestamp column by converting it to datetime
df['job_posted_at_timestamp'] = pd.to_datetime(df['job_posted_at_timestamp'])

# %%
# Check for missing values
print(df.isnull().sum())

# Visualization the missing data
plt.figure(figsize = (10,3))
sns.heatmap(df.isnull(), cbar=True, cmap="Blues_r")
# Out:
# job_id                     0
# job_employment_type        0
# job_title                  0
# job_apply_link             0
# job_description            0
# job_city                   0
# job_country                0
# job_posted_at_timestamp    0
# employer_website           0
# employer_company_type      0
# dtype: int64
# <Axes: >

# %%
# Assign sequential numbers to job entries
df['job_id'] = range(1, len(df) + 1)

# Display modified dataset
# print(df)

# %%
# df.head()

# %%
# Replace "Montréal" with "Montreal" in the 'job_city' column
df['job_city'] = df['job_city'].replace('MontrÃ©al', 'Montreal')

# %%
# df.head()

# %%
df.to_csv(r"C:\Users\ADMIN\Desktop\Project 3 Cleaned transformed_jobs_data.csv", index=False)

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS (EDA)
#
# ### Univariate Analysis

# %%
# Explore job types distribution
job_types_distribution = df['job_employment_type'].value_counts()
print("\nJob Types Distribution:")
print(job_types_distribution)
# Out:
# Job Types Distribution:
# FULLTIME      153
# CONTRACTOR     10
# INTERN          2
# PARTTIME        1
# Name: job_employment_type, dtype: int64

# %%
# Distribution of job types after cleaning
sns.countplot(x='job_employment_type', data=df)
plt.title('Distribution of Job Employment Type')
plt.show();

# %% [markdown]
# ### From this distribution, it's evident that the majority of job postings are for full-time positions, comprising approximately 90% of the dataset.

# %%
# Explore job types distribution
job_types_distribution = df['job_country'].value_counts()
print("\nJob Types by Country:")
print(job_types_distribution)
# Out:
# Job Types by Country:
# US    73
# GB    60
# CA    33
# Name: job_country, dtype: int64

# %%
# Distribution of job types after cleaning
sns.countplot(x='job_country', data=df)
plt.title('Distribution of Job by Country')
plt.show();

# %% [markdown]
# ### The United States (US) leads with the highest number of job postings, followed by Great Britain (GB) and Canada (CA).

# %%
top_job_cities = df['job_city'].value_counts().head(10)
top_job_cities.plot(kind='bar', figsize=(7, 5), color='skyblue')
plt.title('Top 10 Cities with Most Job Postings')
plt.xlabel('Job City')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### London emerges as the top city for job postings, indicating a robust job market in the UK capital. Toronto follows with a significant number of job opportunities, while Jersey City has the least.

# %%
top_job_cities = df['job_city'].value_counts().tail(5)
top_job_cities.plot(kind='bar', figsize=(10, 6), color='blue')
plt.title('least 5 Job Cities')
plt.xlabel('Job City')
plt.ylabel('Count')
plt.show()

# %%
# Count the occurrences of each company type
top_job_cities = df['job_title'].value_counts().head(10)
top_job_cities
# Out:
# Data Engineer                                              31
# Senior Cloud Data Engineer                                 14
# Senior Data Engineer                                       12
# Data Analyst                                                6
# Data Scientist                                              3
# Lead Data Engineer                                          3
# Senior Data Analyst                                         2
# AWS Data Engineer                                           2
# Splunk Data Engineer, Security                              2
# Digital Data Analyst (Entry Level) (Fair Marketing Inc)     2
# Name: job_title, dtype: int64

# %%
top_job_cities = df['job_title'].value_counts().head(10)
top_job_cities.plot(kind='bar', figsize=(7, 5), color='orange')
plt.title('Top 10 Job Title')
plt.xlabel('job_title')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Data Engineer is the most common job title among the postings, with 31 occurrences. This indicates a high demand for professionals skilled in designing, building, and managing data pipelines.

# %% [markdown]
# ### Bivariate Analysis

# %% [markdown]
# ### Industry Insights

# %%
# Count the occurrences of each company type
company_type_counts = df['employer_company_type'].value_counts()
company_type_counts
# Out:
# Consulting           108
# Finance               18
# Manufacturing         10
# Computer Services      9
# Information            7
# Education              3
# Retail                 3
# Staffing               2
# Construction           2
# Utilities              1
# Advertising            1
# Restaurant             1
# Logistics              1
# Name: employer_company_type, dtype: int64

# %%
# Plot the distribution of job postings by company type
plt.figure(figsize=(12, 6))
sns.barplot(x=company_type_counts.index, y=company_type_counts.values, palette='husl')
plt.title('Distribution of Employer Company Type')
plt.xlabel('Company Type')
plt.ylabel('Number of Job Postings')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility
plt.show()

# %% [markdown]
# ### The consulting industry dominates the job market represented in the dataset, with a significant number of job postings.

# %%
# Assuming 'job_posted_at_timestamp' is a timestamp column
df['job_posted_at_timestamp'] = pd.to_datetime(df['job_posted_at_timestamp'])
df.set_index('job_posted_at_timestamp').resample('D').size().plot(linewidth=2)
plt.title('Job Postings Over Time')
plt.xlabel('Date')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### To observe any trends or patterns in job postings over the analyzed time period, after 19th December to 20th December was on decline

# %%
# Example: Relationship between employment type and country
plt.figure(figsize=(10, 6))
sns.countplot(x='job_employment_type', hue='job_country', data=df)
plt.title('Relationship between Employment Type and Country')
plt.show()

# %% [markdown]
# ### The country with the most full time job posting is US follow by GB and Canada

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\admin\appdata\local\anaconda3\lib\site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\admin\appdata\local\anaconda3\lib\site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in c:\users\admin\appdata\local\anaconda3\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in c:\users\admin\appdata\local\anaconda3\lib\site-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin\appdata\local\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\appdata\local\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\appdata\local\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\admin\appdata\local\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\appdata\local\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\admin\appdata\local\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\appdata\local\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\admin\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
from wordcloud import WordCloud

# Example:
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(df['job_title']))
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud for Technology Job Titles')
plt.show()

# %% [markdown]
# ### Skills and Qualifications:

# %%
# !pip install spacy
# Out:
# Requirement already satisfied: spacy in c:\users\admin\appdata\local\anaconda3\lib\site-packages (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\admin\appdata\local\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\admin\appdata\local\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\admin\appdata\local\anaconda3\lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\admin\appdata\local\anaconda3\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\admin\appdata\local\anaconda3\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in c:\users\admin\appdata\local\anaconda3\lib\site-packages (from spacy) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\admin\appdata\local\anaconda3\lib\site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\admin\appdata\local\anaconda3\lib\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\admin\appdata\local\anaconda3\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\admin\appdata\local\anaconda3\lib\site-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\admin\appdata\local\anaconda3\lib\site-packages (from spacy) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\admin\appdata\local\anaconda3\lib\site-packages (from spacy) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\admin\appdata\local\anaconda3\lib\site-packages (from spacy) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\admin\appdata\local\anaconda3\lib\site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\admin\appdata\local\anaconda3\lib\site-packages (from spacy) (1.10.12)
# Requirement already satisfied: jinja2 in c:\users\admin\appdata\local\anaconda3\lib\site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\admin\appdata\local\anaconda3\lib\site-packages (from spacy) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\appdata\local\anaconda3\lib\site-packages (from spacy) (23.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\admin\appdata\local\anaconda3\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\admin\appdata\local\anaconda3\lib\site-packages (from spacy) (1.24.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\admin\appdata\local\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\appdata\local\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\appdata\local\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\appdata\local\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\appdata\local\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\admin\appdata\local\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\admin\appdata\local\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.1.4)
# Requirement already satisfied: colorama in c:\users\admin\appdata\local\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\admin\appdata\local\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\admin\appdata\local\anaconda3\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\admin\appdata\local\anaconda3\lib\site-packages (from jinja2->spacy) (2.1.1)

# %%
# !python -m spacy download en_core_web_sm

# %%
# import spacy
# from collections import Counter

# Assuming your DataFrame is named 'df' and the column with job descriptions is 'job_description'
# Replace 'job_description' with the actual column name in your dataset

# Load spaCy English language model
# nlp = spacy.load("en_core_web_sm")

# Function to extract skills and qualifications from a job description
# def extract_skills_qualifications(text):
 #   doc = nlp(text)
 #   skills = []
 #   qualifications = []

    # Extract entities tagged as 'ORG' (organization) and 'SKILL' (skill) from the text
   # for ent in doc.ents:
     #   if ent.label_ == 'ORG':
       #     qualifications.append(ent.text)
       # elif ent.label_ == 'SKILL':
       #     skills.append(ent.text)

  #  return skills, qualifications

# Apply the function to each job description in the DataFrame
# df['skills'], df['qualifications'] = zip(*df['job_description'].apply(extract_skills_qualifications))

# Flatten the lists of skills and qualifications
# all_skills = [skill for sublist in df['skills'].tolist() for skill in sublist]
# all_qualifications = [qualification for sublist in df['qualifications'].tolist() for qualification in sublist]

# Count the occurrences of each skill and qualification
# skills_counts = Counter(all_skills)
# qualifications_counts = Counter(all_qualifications)

# Print the most common skills and qualifications
# print("Top 10 Skills:")
# print(skills_counts.most_common(10))

# print("\nTop 10 Qualifications:")
# print(qualifications_counts.most_common(10))

# %%
# Job Descriptions Analysis

#import pandas as pd
#import spacy
#from wordcloud import WordCloud
#import matplotlib.pyplot as plt
#from collections import Counter

# Assuming your DataFrame is named 'df' and the column with job descriptions is 'job_description'
# Replace 'job_description' with the actual column name in your dataset

# Load spaCy English language model
# nlp = spacy.load("en_core_web_sm")

# Function to extract and lemmatize tokens from a job description
# def extract_tokens(text):
 #   doc = nlp(text)
  #  tokens = [token.lemma_ for token in doc if not token.is_stop and token.is_alpha]
   # return tokens

# Apply the function to each job description in the DataFrame
# df['tokens'] = df['job_description'].apply(extract_tokens)

# Flatten the list of tokens
# all_tokens = [token for sublist in df['tokens'].tolist() for token in sublist]

# Plot a word cloud to visualize the most common words
# wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(all_tokens))
#plt.figure(figsize=(10, 5))
#plt.imshow(wordcloud, interpolation='bilinear')
#plt.axis('off')
#plt.title('Word Cloud of Job Descriptions')
#plt.show()

# Count the occurrences of each token
# token_counts = Counter(all_tokens)

# Print the most common tokens
#print("Top 10 Most Common Words:")
#print(token_counts.most_common(10))

# %%
# 
text = ' '.join(df['job_description'].dropna())
wordcloud = WordCloud(width=800, height=400, random_state=21, max_font_size=110).generate(text)

plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show(),
# Out:
# (None,)

# %% [markdown]
# ### Conclusion
#
# The comprehensive analysis of job postings and industry insights provides valuable information about the job market in the dataset. These insights can inform strategic decisions for stakeholders, enabling them to effectively navigate the job market landscape and capitalize on emerging opportunities.
#
#
# ### Recommendations
#
#  - Employers and recruiters should focus their hiring efforts in regions with high job demand, such as London, Toronto, and New York.
#
# - Job seekers should consider industries with a high number of job postings, such as consulting and finance, to explore potential career opportunities.
#
# - Continued monitoring and analysis of job posting data can help stakeholders stay abreast of evolving trends and make proactive decisions in the dynamic job market landscape.
